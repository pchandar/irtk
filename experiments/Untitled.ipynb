# %%
# %matplotlib inline
import numpy
import scipy
import psutil
import sklearn
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
import ipyparallel

# %%
import numpy as np
plt.plot(np.sin(np.linspace(0, 2*np.pi)), 'r-o')
